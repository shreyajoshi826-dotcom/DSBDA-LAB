# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyajoshi826-dotcom/DSBDA-LAB/blob/main/DSBDA_LAB_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("iris")

# %%
print(data.head())
print(data.columns)
print(data.info())
print(data.shape)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
# ...

# %%
print(data.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
for column in data.columns[:-1]:
    plt.figure()
    sns.histplot(data[column], kde=True)
    plt.title(f"Histogram of {column}")
    plt.show()

# %%
data.hist(figsize=(10,8))
plt.suptitle("Histograms of Iris Features")
plt.show()

# %%
for column in data.columns[:-1]:
    plt.figure()
    sns.boxplot(y=data[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
for column in data.columns[:-1]:
    plt.figure()
    sns.boxplot(x="species", y=column, data=data)
    plt.title(f"{column} vs Species")
    plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(data.select_dtypes(include=np.number).corr(), annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()
