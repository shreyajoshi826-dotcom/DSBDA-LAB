# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyajoshi826-dotcom/DSBDA-LAB/blob/main/DSBDA_LAB_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas numpy matplotlib seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("titanic")

# %%
print(data.head())
print(data.columns)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data = data.dropna(subset=['age'])

# %%
plt.figure(figsize=(8,6))

sns.boxplot(x='sex', y='age', hue='survived', data=data)

plt.title("Age Distribution by Gender and Survival")
plt.xlabel("Gender")
plt.ylabel("Age")

plt.show()

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10,6))
sns.boxplot(x='sex', y='age', hue='survived', data=data, palette='Set2')

plt.title("Titanic Age Distribution by Gender & Survival", fontsize=14)

plt.show()

# %%
sns.boxplot(x='sex', y='age', hue='survived', data=data)
# Out:
# <Axes: xlabel='sex', ylabel='age'>
